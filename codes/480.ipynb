# %%
import pandas as pd
import numpy as np
import os

# %%
pd.set_option('display.max_columns', None)

# %%
DIST = 480

# %%
def load_test() -> None:
    dir_path = r'C:\machine learning\gb_greyhound\grayhound\data\test'
    file_name = 'prepared_test_2024-08-28.csv'
    file_path = os.path.join(dir_path, file_name)
    return pd.read_csv(file_path)

def load_dataset() -> None:
    dir_path = r'C:\machine learning\gb_greyhound\grayhound\data\train\datasets'
    file_name = 'dataset_480.0.csv'
    file_path = os.path.join(dir_path, file_name)
    return pd.read_csv(file_path, low_memory=False)

# %%
testing = load_dataset()

# %%
to_drop = ['SP', 'dogBorn', 'dogColour', 'dogId', 'dogSeason', 
           'dogSex', 'dogSire', 'dogSire', 'meetingId', 
           'ownerName', 'raceForecast', 'raceId', 'raceNumber', 
           'raceHandicap', 'racePrizes', 'raceTricast', 'raceType', 
           'resultAdjustedTime', 'resultMarketCnt', 'resultMarketPos',
           'trainerName', 'trapHandicap']

testing_tr = testing.drop(to_drop, axis=1)

# %%
testing_tr['raceDate'] = pd.to_datetime(testing_tr['raceDate'], format='%d/%m/%Y')

# %%
testing_tr['forecast'] = testing_tr['resultPriceNumerator'] / testing_tr['resultPriceDenominator']

# %%
def get_last_5_races(row, df):
    current_race_date = row['raceDate']
    current_dog_name = row['dogName']
    
    try:
        valid_races = df[(df['dogName'] == current_dog_name) & df['raceDate'].notna()]
        valid_races = valid_races[valid_races['raceDate'] < current_race_date]

        previous_races = valid_races.sort_values(by='raceDate', ascending=False)
        last_5_races = previous_races.head(5)
        
        by = []
        comments = []
        dist = []
        finished = []
        going = []
        price_dens = []
        price_nums = []
        race_grade = []
        run_time = []
        sec_time = []
        trap = []
        weight = []
        
        for _, race in last_5_races.iterrows():
            by.append(race['resultBtnDistance'])
            comments.append(race['resultComment'])
            dist.append(race['raceDistance'])
            finished.append(race['resultPosition'])
            going.append(race['raceGoing'])
            price_dens.append(race['resultPriceDenominator'])
            price_nums.append(race['resultPriceNumerator'])
            race_grade.append(race['raceClass'])
            run_time.append(race['resultRunTime'])
            sec_time.append(race['resultSectionalTime'])
            trap.append(race['trapNumber'])
            weight.append(race['resultDogWeight'])

        # Если количество гонок меньше 5, заполняем недостающие элементы None
        while len(run_time) < 5:
            by.append(None)
            comments.append(None)
            dist.append(None)
            finished.append(None)
            going.append(None)
            price_dens.append(None)
            price_nums.append(None)
            race_grade.append(None)
            run_time.append(None)
            sec_time.append(None)
            trap.append(None)
            weight.append(None)

        result = (by + comments + dist + 
                  finished + going + 
                  price_dens + price_nums
                 + race_grade + run_time + 
                  sec_time + trap + weight)

        return result
    except Exception as e:
        print(f"Error at row {row.name}: {e}")
        raise

# %%
results = testing_tr.apply(lambda row: get_last_5_races(row, testing_tr), axis=1)
race_results_full = pd.DataFrame(results.tolist(), columns=[
    'by_1', 'by_2', 'by_3', 'by_4', 'by_5',
    'comments_1', 'comments_2', 'comments_3', 'comments_4', 'comments_5',
    'dist_1', 'dist_2', 'dist_3', 'dist_4', 'dist_5',
    'finished_1', 'finished_2', 'finished_3', 'finished_4', 'finished_5',
    'going_1', 'going_2', 'going_3', 'going_4', 'going_5',
    'price_dens_1', 'price_dens_2', 'price_dens_3', 'price_dens_4', 'price_dens_5',
    'price_nums_1', 'price_nums_2', 'price_nums_3', 'price_nums_4', 'price_nums_5',
    'race_grade_1', 'race_grade_2', 'race_grade_3', 'race_grade_4', 'race_grade_5',
    'run_time_1', 'run_time_2', 'run_time_3', 'run_time_4', 'run_time_5',
    'sec_time_1', 'sec_time_2', 'sec_time_3', 'sec_time_4', 'sec_time_5',
    'trap_1', 'trap_2', 'trap_3', 'trap_4', 'trap_5',
    'weight_1', 'weight_2', 'weight_3', 'weight_4', 'weight_5'
])

# %%
testing_full = pd.concat([testing_tr, race_results_full], axis=1)

# %%
testing_full.tail()
# Out:
#                dogName raceClass   raceDate  raceDistance  raceGoing  \
# 766256   Edermine King        A8 2024-08-03         480.0        0.0
# 766257     Rubys Charm        A8 2024-08-03         480.0        0.0
# 766258   Ballarue Girl        A8 2024-08-03         480.0        0.0
# 766259  Circleofdreams        A8 2024-08-03         480.0        0.0
# 766260  Rathsilla Puno        A8 2024-08-03         480.0        0.0
#
#         raceTime resultBtnDistance     resultComment  resultDogWeight  \
# 766256  22:11:00                 3  SAw,EP,VeryWide4             27.1
# 766257  22:11:00                 1    EP,Mid,Ld- 1/2             24.8
# 766258  22:11:00             3 3/4          SAw,Wide             28.0
# 766259  22:11:00               3/4      Rls,Eased2&3             25.6
# 766260  22:11:00               DNF   Mid,Ck&Fell 1/2             27.8
#
#         resultPosition  resultPriceDenominator  resultPriceNumerator  \
# 766256             2.0                     4.0                   9.0
# 766257             3.0                     8.0                  15.0
# 766258             4.0                     1.0                  28.0
# 766259             5.0                     1.0                   4.0
# 766260             6.0                     1.0                   6.0
#
#         resultRunTime  resultSectionalTime   trackName  trapNumber  forecast  \
# 766256          29.68                 3.71  Perry Barr           5     2.250
# 766257          29.76                 3.59  Perry Barr           3     1.875
# 766258          30.06                 3.78  Perry Barr           6    28.000
# 766259          30.12                 3.70  Perry Barr           1     4.000
# 766260            NaN                 3.69  Perry Barr           4     6.000
#
#          by_1   by_2   by_3   by_4  by_5                comments_1  \
# 766256    1/2   None   None   None  None          SAwEP,FcdCk&Bmp1
# 766257  3 1/2      2  2 1/2  4 1/4     4  EP,Crd1&2,FcdCk 1/2,Stb4
# 766258    1/2  2 1/4    3/4  4 1/2   3/4             CrdStt&2,Wide
# 766259  2 3/4    NaN    1/2  1 3/4   3/4              EP,Rls,RanOn
# 766260  1 3/4     HD    1/2  1 3/4   3/4       CrdRunUp,Crd&FcdCk1
#
#                 comments_2              comments_3           comments_4  \
# 766256                None                    None                 None
# 766257        SAwEP,Crd1&2        EP,Mid,Ld1-RunIn       BlkStt,Crd 3/4
# 766258           VSAw,Wide             Wide,FcdCk1             SAw,Wide
# 766259  Rls,LdRunIn-NrLine  LckEP,Eased3,RanOnLate  StbStt,Eased3,RanOn
# 766260        SAw,Mid,Crd1  Mid,Crd1,Ld2-RunIn,Crd          EP,Mid,Bmp1
#
#                 comments_5  dist_1  dist_2  dist_3  dist_4  dist_5  \
# 766256                None   480.0     NaN     NaN     NaN     NaN
# 766257       CrdStt,EP,Mid   480.0   480.0   480.0   480.0   480.0
# 766258           VSAw,Wide   480.0   480.0   480.0   480.0   480.0
# 766259      Rls,Eased&Crd3   480.0   480.0   480.0   480.0   480.0
# 766260  EP,Mid,Ld 1/2-NrLn   480.0   480.0   480.0   480.0   480.0
#
#         finished_1  finished_2  finished_3  finished_4  finished_5  going_1  \
# 766256         3.0         NaN         NaN         NaN         NaN    -10.0
# 766257         5.0         4.0         3.0         6.0         6.0      0.0
# 766258         6.0         4.0         6.0         5.0         4.0      0.0
# 766259         3.0         2.0         4.0         3.0         5.0      0.0
# 766260         6.0         4.0         3.0         5.0         2.0      0.0
#
#         going_2  going_3  going_4  going_5  price_dens_1  price_dens_2  \
# 766256      NaN      NaN      NaN      NaN           1.0           NaN
# 766257      0.0      0.0    -40.0     10.0           1.0           1.0
# 766258      0.0     10.0     10.0    -10.0           1.0           1.0
# 766259      NaN     10.0    -10.0     10.0           1.0           1.0
# 766260      0.0      0.0      0.0      0.0           2.0           2.0
#
#         price_dens_3  price_dens_4  price_dens_5  price_nums_1  price_nums_2  \
# 766256           NaN           NaN           NaN           7.0           NaN
# 766257           1.0           1.0           1.0           5.0          20.0
# 766258           1.0           1.0           1.0          14.0          28.0
# 766259           8.0           1.0           1.0           5.0           7.0
# 766260           1.0           2.0           1.0           9.0           5.0
#
#         price_nums_3  price_nums_4  price_nums_5 race_grade_1 race_grade_2  \
# 766256           NaN           NaN           NaN           A8         None
# 766257           7.0          12.0           7.0           A8           A7
# 766258          28.0          18.0          18.0           A9           A9
# 766259          15.0           2.0          10.0           A8           A8
# 766260           4.0           7.0           4.0           A8           A8
#
#        race_grade_3 race_grade_4 race_grade_5  run_time_1  run_time_2  \
# 766256         None         None         None       30.16         NaN
# 766257           A7           A7           A7       30.19       29.84
# 766258           A9           A9           A9       30.53       30.44
# 766259           A8           A8           A8       29.82       29.96
# 766260           A8           A8           A8       30.41       30.03
#
#         run_time_3  run_time_4  run_time_5  sec_time_1  sec_time_2  \
# 766256         NaN         NaN         NaN        3.76         NaN
# 766257       29.74       30.54       29.94        3.51        3.62
# 766258       30.61       30.73       30.83        3.87        3.90
# 766259       30.10       30.36       29.94        3.72        3.68
# 766260       29.89       30.00       29.72        3.72        3.66
#
#         sec_time_3  sec_time_4  sec_time_5  trap_1  trap_2  trap_3  trap_4  \
# 766256         NaN         NaN         NaN     5.0     NaN     NaN     NaN
# 766257        3.56        3.69        3.64     4.0     3.0     4.0     4.0
# 766258        3.61        3.82        3.83     5.0     6.0     5.0     6.0
# 766259        3.81        3.95        3.71     1.0     1.0     1.0     2.0
# 766260        3.73        3.64        3.68     4.0     4.0     4.0     4.0
#
#         trap_5  weight_1  weight_2  weight_3  weight_4  weight_5
# 766256     NaN      27.2       NaN       NaN       NaN       NaN
# 766257     4.0      24.4      24.9      24.4      24.3      24.5
# 766258     6.0      28.1      28.1      27.8      27.7      27.5
# 766259     2.0      26.2      26.2      26.2      27.0      25.9
# 766260     3.0      27.8      27.3      27.2      27.7      27.3

# %%
grades = testing_full['raceClass'].unique()

# %%
stats = {}
for grade in grades:
    grade_len = len(testing_full[testing_full['raceClass'] == grade])
    grade_rows = testing_full[testing_full['raceClass'] == grade]
    grade_stat = grade_rows[['resultRunTime', 'resultSectionalTime', 'resultDogWeight', 'raceGoing', 'forecast']].agg(['mean', 'min', 'max'])
    stats[grade] = {'count': grade_len, 'statistics': grade_stat}

# %%
comparison_results = {}

for grade, data in stats.items():
    if grade == 'A1':
        continue
        
    a1_stats = stats['A1']['statistics']
    current_stats = data['statistics']
    diff = current_stats - a1_stats
    comparison_results[grade] = {'len': data['count'], 'diff': diff}

for grade, diff in comparison_results.items():
    print(f"Разница между A1 и {grade}:")
    print(diff)
    print("\n")
# Out:
# Разница между A1 и A4:
# {'len': 91631, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  forecast
# mean       0.411647            -0.076568        -1.561533   2.017591 -0.097576
# min      -11.700000             0.000000         0.000000 -30.000000  0.100000
# max        0.210000             8.740000         1.400000 -10.000000  7.000000}
#
#
# Разница между A1 и A8:
# {'len': 65201, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  forecast
# mean       0.930182            -0.095353        -2.728733    4.26684  0.066042
# min        0.420000             0.000000         0.000000  -10.00000  0.063636
# max        0.790000           -30.010000         1.500000    0.00000  7.000000}
#
#
# Разница между A1 и A6:
# {'len': 84966, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       0.621022              0.00745        -2.130492   2.627718
# min        0.170000              0.00000         0.000000 -60.000000
# max        0.070000            -28.71000        -0.400000   0.000000
#
#        forecast
# mean  -0.045344
# min    0.063636
# max   17.000000  }
#
#
# Разница между A1 и A2:
# {'len': 67828, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight    raceGoing  \
# mean       0.179625            -0.116536        -0.665697     0.547015
# min        0.060000             0.000000         0.000000     0.000000
# max       -0.920000           -25.010000         0.800000  1866.000000
#
#       forecast
# mean -0.109455
# min   0.033333
# max   0.000000  }
#
#
# Разница между A1 и A5:
# {'len': 89518, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       0.523437            -0.052783        -1.889338   2.559433
# min        0.160000             0.000000         0.000000 -30.000000
# max        1.710000           -10.010000         0.400000 -10.000000
#
#        forecast
# mean  -0.073241
# min   -0.077778
# max   17.000000  }
#
#
# Разница между A1 и A3:
# {'len': 84466, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  forecast
# mean       0.314792            -0.138029        -1.146755   1.316198 -0.121415
# min        0.020000             0.000000         0.000000 -10.000000  0.033333
# max       -0.150000           -23.580000         0.400000  10.000000  7.000000}
#
#
# Разница между A1 и A7:
# {'len': 72388, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  forecast
# mean       0.741108             0.013075        -2.439203   3.356305  0.019917
# min        0.380000             0.000000         0.000000 -30.000000  0.033333
# max        0.440000             7.480000         2.000000 -10.000000  7.000000}
#
#
# Разница между A1 и HP:
# {'len': 72630, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  forecast
# mean       0.586494                  NaN        -1.755987  19.412318 -0.609654
# min      -27.650000                  NaN         0.000000  20.000000  0.144444
# max        7.720000                  NaN         1.300000  20.000000  0.000000}
#
#
# Разница между A1 и A9:
# {'len': 28442, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       1.114686            -0.478468        -2.980314   4.147632
# min        0.720000             0.000000         0.000000  30.000000
# max        0.330000           -39.710000         0.900000 -10.000000
#
#        forecast
# mean   0.166634
# min    0.033333
# max   33.000000  }
#
#
# Разница между A1 и OR:
# {'len': 43704, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight    raceGoing  \
# mean      -0.057976            -0.214687          0.38742     8.310006
# min       -0.640000             0.000000          0.00000    20.000000
# max        5.880000           -36.950000          0.70000  2055.000000
#
#        forecast
# mean   2.325781
# min   -0.228571
# max   67.000000  }
#
#
# Разница между A1 и A10:
# {'len': 9583, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       0.929603             0.291219        -2.860291   1.861564
# min        1.010000             0.450000        21.100000  40.000000
# max        0.850000           -76.050000         0.200000 -10.000000
#
#        forecast
# mean   0.405421
# min    0.100000
# max   17.000000  }
#
#
# Разница между A1 и IT:
# {'len': 2485, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.388795            -0.240064        -1.600795    4.010521
# min       -0.010000             2.310000        21.700000  110.000000
# max       -1.190000           -45.710000         0.600000  -30.000000
#
#        forecast
# mean   0.553406
# min    0.063636
# max   33.000000  }
#
#
# Разница между A1 и P4:
# {'len': 786, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.783495             0.596611        -2.373674   13.880439
# min        0.340000             3.970000        22.700000  130.000000
# max       -1.390000           -79.360000        -3.200000  -10.000000
#
#        forecast
# mean   0.184315
# min    0.500000
# max  -13.000000  }
#
#
# Разница между A1 и P3:
# {'len': 1230, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.594698             0.609274        -1.931923   13.144304
# min        0.590000             0.000000        21.600000  120.000000
# max       -1.110000           -77.080000        -3.200000  -30.000000
#
#        forecast
# mean   0.133754
# min    0.500000
# max  -13.000000  }
#
#
# Разница между A1 и B1:
# {'len': 635, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean      -0.015742              0.07637        -0.256902   44.478077
# min       -0.210000              3.10000        24.200000  150.000000
# max       -1.840000            -44.85000         1.100000   20.000000
#
#        forecast
# mean  -0.214814
# min    0.271429
# max  -13.000000  }
#
#
# Разница между A1 и P1:
# {'len': 264, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.356787             0.589037        -2.346312   17.409851
# min        0.560000             4.140000        21.400000  150.000000
# max       -2.010000           -79.870000        -4.800000  -30.000000
#
#       forecast
# mean  -0.05961
# min    0.70000
# max  -17.00000  }
#
#
# Разница между A1 и P6:
# {'len': 336, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.101197             0.116701        -1.441018    2.681771
# min        0.450000             4.030000        23.500000  130.000000
# max       -2.280000           -79.390000        -3.400000  -30.000000
#
#        forecast
# mean  -0.236344
# min    0.500000
# max  -17.000000  }
#
#
# Разница между A1 и B5:
# {'len': 618, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.314466             -0.02035        -1.172927   11.770905
# min        0.470000              3.11000         0.000000  120.000000
# max       -0.100000            -80.37000        -3.200000    0.000000
#
#       forecast
# mean  0.697629
# min   0.500000
# max  -5.000000  }
#
#
# Разница между A1 и IV:
# {'len': 336, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean      -0.336062            -0.000025         0.623235    1.70757
# min       -0.230000             3.150000        23.400000  130.00000
# max       -2.370000           -79.680000        -2.800000  -20.00000
#
#        forecast
# mean   2.376327
# min    0.271429
# max   17.000000  }
#
#
# Разница между A1 и P2:
# {'len': 390, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean        0.40542             0.523982        -1.955315   15.252988
# min         0.78000             3.230000        23.200000  130.000000
# max        -1.76000           -79.810000        -3.000000  -20.000000
#
#        forecast
# mean   0.082297
# min    0.500000
# max  -19.000000  }
#
#
# Разница между A1 и B6:
# {'len': 428, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.422918             0.019248        -0.870639    6.253664
# min        0.430000             3.210000        22.200000  110.000000
# max        0.220000           -79.940000        -3.400000    0.000000
#
#       forecast
# mean  0.963898
# min   0.271429
# max   0.000000  }
#
#
# Разница между A1 и B4:
# {'len': 516, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.414025            -0.091029        -1.575061   22.995363
# min       -0.190000             1.260000        22.400000  120.000000
# max        0.020000           -79.750000        -1.700000   20.000000
#
#        forecast
# mean   0.427461
# min    0.200000
# max  -13.000000  }
#
#
# Разница между A1 и P5:
# {'len': 282, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean      -0.046911             0.044459         -1.39218    8.924244
# min        0.380000             3.990000         23.60000  140.000000
# max        0.410000           -80.390000         -2.50000  -20.000000
#
#        forecast
# mean  -0.408298
# min    0.950000
# max  -21.000000  }
#
#
# Разница между A1 и S2:
# {'len': 6, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       13.39776             10.01005        -4.853492        NaN
# min        14.49000             13.98000        22.700000        NaN
# max         9.85000            -70.63000        -8.700000        NaN
#
#        forecast
# mean   0.033339
# min    1.700000
# max  -25.000000  }
#
#
# Разница между A1 и H1:
# {'len': 348, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.929694             0.024873         1.079694    0.240733
# min        0.830000             3.240000        26.900000  130.000000
# max       -1.120000           -34.010000        -3.100000  -30.000000
#
#       forecast
# mean  1.294687
# min   0.100000
# max   0.000000  }
#
#
# Разница между A1 и D4:
# {'len': 6, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean     -12.343906                  NaN        -0.120159        NaN
# min      -11.340000                  NaN        26.300000        NaN
# max      -15.950000                  NaN        -6.700000        NaN
#
#        forecast
# mean  -0.258328
# min    1.950000
# max  -26.000000  }
#
#
# Разница между A1 и H2:
# {'len': 246, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean        0.96693            -0.040812        -0.127786    6.115733
# min         0.85000             3.240000        25.700000  130.000000
# max        -0.83000           -79.730000        -4.600000  -30.000000
#
#       forecast
# mean  0.792120
# min   0.144444
# max  -8.000000  }
#
#
# Разница между A1 и KS:
# {'len': 36, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       0.818348            -0.800784        -2.567381     8.7824
# min        1.600000             3.260000        24.700000   155.0000
# max       -2.130000           -81.380000        -6.800000   -40.0000
#
#        forecast
# mean  -0.152772
# min    0.500000
# max  -21.000000  }
#
#
# Разница между A1 и P8:
# {'len': 488, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.470449             0.132872        -2.383311    0.455982
# min        0.810000             4.040000        23.400000  110.000000
# max       -1.360000           -79.910000        -3.600000  -30.000000
#
#        forecast
# mean  -0.152343
# min    0.700000
# max  -17.000000  }
#
#
# Разница между A1 и B8:
# {'len': 316, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.571375            -0.154715        -2.828071   10.831949
# min        0.720000             3.140000        21.700000  140.000000
# max       -1.520000           -80.410000        -4.700000    0.000000
#
#        forecast
# mean   0.528829
# min    0.427273
# max  -21.000000  }
#
#
# Разница между A1 и B7:
# {'len': 316, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.400603            -0.066342         -1.89443   11.141707
# min        0.380000             3.160000         20.70000  130.000000
# max       -1.560000           -79.930000         -3.50000   10.000000
#
#        forecast
# mean   0.714811
# min    0.533333
# max  -13.000000  }
#
#
# Разница между A1 и P7:
# {'len': 435, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.168795             0.100113        -1.789785    3.426078
# min        0.330000             4.020000        23.600000  120.000000
# max        0.080000           -80.210000        -3.900000  -20.000000
#
#        forecast
# mean  -0.094210
# min    0.366667
# max  -17.000000  }
#
#
# Разница между A1 и P9:
# {'len': 144, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.429451             0.110135        -2.508845   11.246168
# min        0.840000             0.000000        22.200000  110.000000
# max       -2.090000           -80.210000        -3.400000  -30.000000
#
#        forecast
# mean   0.012420
# min    0.366667
# max  -21.000000  }
#
#
# Разница между A1 и B3:
# {'len': 917, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.578502            -0.093684        -1.621978   38.720583
# min       -0.160000             3.050000        22.200000  130.000000
# max       -0.800000           -79.740000        -0.900000   10.000000
#
#       forecast
# mean  0.044355
# min   0.315385
# max  -8.000000  }
#
#
# Разница между A1 и D5:
# {'len': 6, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean      -12.26224                  NaN         0.763175   12.115733
# min       -11.39000                  NaN        30.200000  170.000000
# max       -15.61000                  NaN        -4.300000  -50.000000
#
#        forecast
# mean  -0.966661
# min    1.700000
# max  -28.000000  }
#
#
# Разница между A1 и T3:
# {'len': 18, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  forecast
# mean       1.325942              0.10005        -0.186825   -21.2176       NaN
# min        2.130000              3.40000        25.800000   110.0000       NaN
# max       -1.880000            -79.77000        -1.700000   -60.0000       NaN}
#
#
# Разница между A1 и B2:
# {'len': 1196, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       0.224965            -0.150995        -0.853026   43.895394
# min       -0.250000             3.050000        24.100000  110.000000
# max       -1.340000           -79.710000        -3.400000   20.000000
#
#       forecast
# mean -0.065606
# min   0.315385
# max   0.000000  }
#
#
# Разница между A1 и D2:
# {'len': 6, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean      -13.35224                  NaN         0.869841   12.115733
# min       -12.46000                  NaN        28.300000  170.000000
# max       -16.69000                  NaN        -6.100000  -50.000000
#
#        forecast
# mean  -0.699995
# min    1.450000
# max  -26.000000  }
#
#
# Разница между A1 и T2:
# {'len': 2, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean        1.54776            -0.751617        -1.270159  -47.884267
# min         2.53000             3.440000        29.600000  110.000000
# max        -1.89000           -81.530000       -10.400000 -110.000000
#
#       forecast
# mean       NaN
# min        NaN
# max        NaN  }
#
#
# Разница между A1 и T1:
# {'len': 5, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean        2.13776            -0.691617         0.229841  -47.884267
# min         2.79000             3.390000        29.200000  110.000000
# max        -1.32000           -81.280000        -7.600000 -110.000000
#
#       forecast
# mean       NaN
# min        NaN
# max        NaN  }
#
#
# Разница между A1 и S1:
# {'len': 5, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       12.57276                  NaN        -0.595159        NaN
# min        13.65000                  NaN        28.600000        NaN
# max         9.26000                  NaN        -8.200000        NaN
#
#        forecast
# mean  -1.924995
# min    0.700000
# max  -29.000000  }
#
#
# Разница между A1 и OR1:
# {'len': 1422, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       -0.44704            -0.207598         0.456991    8.462765
# min        -0.66000             0.000000        24.100000  140.000000
# max        -1.94000           -78.860000         0.200000  -10.000000
#
#        forecast
# mean   3.896598
# min   -0.157143
# max   17.000000  }
#
#
# Разница между A1 и OR3:
# {'len': 1236, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight  raceGoing  \
# mean       -0.22431             -0.04061         0.364661  15.581079
# min        -0.54000              3.03000        23.100000  70.000000
# max        -1.75000            -79.89000         0.000000   0.000000
#
#        forecast
# mean   2.770588
# min   -0.200000
# max   17.000000  }
#
#
# Разница между A1 и OR2:
# {'len': 330, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean       -0.12806             0.455154        -1.225018   13.570278
# min        -0.09000             4.340000        24.700000  140.000000
# max        -2.71000           -80.040000        -2.000000  -20.000000
#
#       forecast
# mean  3.395816
# min  -0.014286
# max   0.000000  }
#
#
# Разница между A1 и P10:
# {'len': 6, 'diff':       resultRunTime  resultSectionalTime  resultDogWeight   raceGoing  \
# mean        0.68776              0.33005         0.163175   22.115733
# min         1.37000              4.46000        27.500000  180.000000
# max        -2.90000            -80.41000        -7.400000  -40.000000
#
#        forecast
# mean  -0.008328
# min    1.450000
# max  -24.000000  }

# %%
output_df = pd.concat({k: v['statistics'] for k, v in stats.items()}, axis=1)

import json

with open(f'{DIST}_statistics.json', 'w') as f:
    json.dump({k: {'count': v['count'], 'statistics': v['statistics'].to_dict()} for k, v in stats.items()}, f, indent=4)

# %%
diff_df = pd.concat({k: v['diff'] for k, v in comparison_results.items()}, axis=1)
with open(f'{DIST}_comparison_results.json', 'w') as f:
        json.dump({k: {'count': v['len'], 'diff': v['diff'].to_dict()} for k, v in comparison_results.items()}, f, indent=4)

# %%
grades
# Out:
# array(['A4', 'A8', 'A6', 'A2', 'A5', 'A3', 'A1', 'A7', 'HP', 'A9', 'OR',
#        'A10', 'IT', 'P4', 'P3', 'B1', 'P1', 'P6', 'B5', 'IV', 'P2', 'B6',
#        'B4', 'P5', 'S2', 'H1', 'D4', 'H2', 'KS', 'P8', 'B8', 'B7', 'P7',
#        'P9', 'B3', 'D5', 'T3', 'B2', 'D2', 'T2', 'T1', 'S1', 'OR1', 'OR3',
#        'OR2', 'P10'], dtype=object)

# %%
to_drop = ['OR', 'IT', 'P4', 'P3', 'P1', 'P6', 'IV', 'P2', 'P5', 'S2', 'H1', 'D4', 'H2', 'KS', 'P8', 'P7', 'P9', 'D5', 'T3', 'D2', 'T2', 'T1', 'S1', 'P10']
testing_full_dropped = testing_full[~testing_full['raceClass'].isin(to_drop)]
testing_full_dropped = testing_full_dropped[~testing_full_dropped['race_grade_1'].isin(to_drop)]
testing_full_dropped = testing_full_dropped[~testing_full_dropped['race_grade_2'].isin(to_drop)]
testing_full_dropped = testing_full_dropped[~testing_full_dropped['race_grade_3'].isin(to_drop)]
testing_full_dropped = testing_full_dropped[~testing_full_dropped['race_grade_4'].isin(to_drop)]
testing_full_dropped = testing_full_dropped[~testing_full_dropped['race_grade_5'].isin(to_drop)]

# %%
print(len(testing_full))
print(len(testing_full_dropped))
# Out:
# 766261
# 668013

# %% [markdown]
# # Отделение

# %%
testing_full_dropped.dropna(subset=['dogName'], axis=0, inplace=True)

# %%
testing_full_dropped = testing_full_dropped.replace(['', ' ', None, 'NaN'], np.nan)

# %%
def convert_dist_by(dist_by):
    shorthand_mapping = {
        'HD': 0.1,
        'SH': 0.2,
        'NK': 0.3,
        'DIS': 30.0,
        'DH': 0.0,
        'DNF': 50,
    }

    if dist_by is None or pd.isna(dist_by) or dist_by == '.':
        return None
    else:
        try:
            if dist_by in shorthand_mapping:
                return shorthand_mapping[dist_by]
            parts = dist_by.split()
            if len(parts) == 1:  # If there's only one value in the string
                if '/' in parts[0]:  # If it's a fraction (e.g., '3/4')
                    num, denom = parts[0].split('/')
                    return float(num) / float(denom)
                else:  # If it's a whole number (e.g., '1')
                    return float(parts[0])
            elif len(parts) == 2:  # If there are two parts (e.g., '1 3/4')
                whole_num = float(parts[0])
                num, denom = parts[1].split('/')
                return whole_num + (float(num) / float(denom))
            else:
                raise ValueError(f"Unexpected format: {dist_by}")
        except Exception as e:
            print(f"Error converting distance: {dist_by}, {e}")
            return None

# %%
for i in range(5):
    testing_full_dropped.loc[:, f'by_{i+1}'] = testing_full_dropped[f'by_{i+1}'].apply(convert_dist_by).round(2)

# %%
def set_adv_lagg(pos, by):
    if by is None or pd.isna(by):
        return None
    result = np.round(by * 0.8, 2) if pos == 1 else np.round(by * -0.8, 2)
    print(f"pos: {pos}, by: {by}, result: {result}")  # Для отладки
    return result

# %%
for i in range(5):
    testing_full_dropped[f'by_{i+1}'] = testing_full_dropped.apply(lambda row: set_adv_lagg(row[f'finished_{i+1}'], row[f'by_{i+1}']), axis=1)

# %%
testing_full_dropped = testing_full_dropped.dropna(subset=['dist_1', 'dist_2', 'dist_3'], axis=0)

# %%
def convert_dist_to_int(dist):
    if isinstance(dist, str):
        cleaned_dist = re.sub(r'[^\d]', '', dist)
        if cleaned_dist:
            return int(cleaned_dist)
        else:
            return np.nan
    elif isinstance(dist, float) and pd.isna(dist):
        return np.nan
    else:
        return dist

# %%
for i in range(5):
    testing_full_dropped.loc[:, f'dist_{i+1}'] = testing_full_dropped[f'dist_{i+1}'].apply(lambda dist: convert_dist_to_int(dist))

# %%
for i in range(5):
    testing_full_dropped[f'odds_{i+1}'] = testing_full_dropped[f'price_nums_{i+1}'] / testing_full_dropped[f'price_dens_{i+1}']

# %%
def convert_forecast(sp):
    if isinstance(sp, str):
        sp = re.sub(r'[^\d/]', '', sp)
        if sp != '':
            num, den = sp.split('/')
            return int(num) / int(den)
        else:
            return np.nan
    elif isinstance(sp, float) and pd.isna(sp):
        return np.nan
    else:
        return sp

# %%
testing_full_dropped.loc[:, 'forecast'] = testing_full_dropped['forecast'].apply(lambda sp: convert_forecast(sp))

for i in range(5):
    testing_full_dropped.loc[:, f'odds_{i+1}'] = testing_full_dropped[f'odds_{i+1}'].apply(lambda sp: convert_forecast(sp))

# %%
def convert_signed_string_to_number(gng):
    try:
        return int(gng.strip())
    except ValueError:
        return np.nan

# %%
for i in range(5):
    testing_full_dropped.loc[:, f'going_{i+1}'] = pd.to_numeric(testing_full_dropped[f'going_{i+1}'], errors='coerce').fillna(0).astype('int32')

# %%
import joblib
def save_encoder(encoder, dist):
    dir_name = os.path.join("grayhound", "encoders")
    os.makedirs(dir_name, exist_ok=True)
    joblib.dump(encoder, os.path.join(dir_name, f"encoder_{dist}.pkl"))

# %%
testing_full_dropped = testing_full_dropped.dropna(subset=['resultPosition'])

# %%
from sklearn.preprocessing import OrdinalEncoder

columns_cat = ['raceClass', 'race_grade_1', 'race_grade_2', 'race_grade_3', 'race_grade_4', 'race_grade_5', 'trackName']
testing_cat = testing_full_dropped[columns_cat]

encoder = OrdinalEncoder()
encoder.fit(testing_cat)

save_encoder(encoder, 480)

testing_encoded = encoder.transform(testing_cat)
testing_encoded_df = pd.DataFrame(testing_encoded, columns=columns_cat)
testing_full_dropped[columns_cat] = testing_encoded_df

# %% [markdown]
# # -------------------------------------

# %%
to_drop = ['dogName', 'raceDate', 'raceTime', 
           'resultBtnDistance', 'resultPriceDenominator', 
           'resultPriceNumerator', 'resultRunTime', 
           'resultSectionalTime', 'resultDogWeight',
           'raceGoing', 'price_dens_1', 'price_dens_2', 'price_dens_3', 'price_dens_4', 'price_dens_5', 
           'price_nums_1', 'price_nums_2', 'price_nums_3', 'price_nums_4', 'price_nums_5',
           'resultComment', 'comments_1', 'comments_2', 'comments_3', 'comments_4', 'comments_5']

testing_full_dropped = testing_full_dropped.drop(to_drop, axis=1)
testing_full_dropped = testing_full_dropped.dropna(subset=['resultPosition'])

# %%
def save_imputer(imputer, dist):
    dir_name = os.path.join("grayhound", "imputers")
    os.makedirs(dir_name, exist_ok=True)
    joblib.dump(imputer, os.path.join(dir_name, f"imputer_{dist}.pkl"))

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=3, weights='distance', keep_empty_features=False)
imputer.fit(testing_full_dropped)

save_imputer(imputer, 480)

X = imputer.transform(testing_full_dropped)

# %%
testing_ready = pd.DataFrame(X, columns=testing_full_dropped.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 testing_ready = pd.DataFrame(X, columns=testing_full_dropped.columns)
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File C:\anaconda\Lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File C:\anaconda\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (587786, 51), indices imply (587786, 56)

# %%
for i in range(5):
    testing_ready.loc[testing_ready[f'finished_{i+1}'] == 1, f'by_{i+1}'] *= -1

# %%
for i in range(5):
    testing_ready.loc[:, f'dist_{i+1}'] = testing_ready.loc[:, f'dist_{i+1}'].round()
    testing_ready.loc[:, f'finished_{i+1}'] = testing_ready.loc[:, f'finished_{i+1}'].round()
    testing_ready.loc[:, f'trap_{i+1}'] = testing_ready.loc[:, f'trap_{i+1}'].round()

# %% [markdown]
# # ------------------------

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
testing_train = testing_ready.drop(['raceDistance', 'trackName', 'dist_1', 'dist_2', 'dist_3', 'dist_4', 'dist_5'], axis=1)

# %%
testing_train.to_csv(r'C:\machine learning\gb_greyhound\grayhound\data\test\TO_CONTINUE.csv')

# %%
testing_train = pd.read_csv(r'C:\machine learning\gb_greyhound\grayhound\data\test\TO_CONTINUE.csv')

# %%
from sklearn.model_selection import train_test_split

y = testing_train['resultPosition']
X = testing_train.drop(['resultPosition'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
testing_sclaed = scaler.fit_transform(X_train)

# %%
from sklearn.preprocessing import MinMaxScaler

min_max = MinMaxScaler()
testing_min_max = min_max.fit_transform(X_train)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

param_grid = [
    {'n_estimators': [3, 10, 30], 'max_features': [5, 10, 15, 25, 44]},
    {'bootstrap': [False], 'n_estimators': [3, 10, 30], 'max_features': [5, 10, 15, 25, 44]}
]

model = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(model, param_grid, cv=5, 
                           scoring='neg_mean_squared_error',
                           return_train_score=True)

# %%
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid=[{'max_features': [5, 10, 15, 25, 44],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False],
#                           'max_features': [5, 10, 15, 25, 44],
#                           'n_estimators': [3, 10, 30]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'bootstrap': False, 'max_features': 10, 'n_estimators': 30}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 2.293614216529695 {'max_features': 5, 'n_estimators': 3}
# 2.1564952081930397 {'max_features': 5, 'n_estimators': 10}
# 2.0912015732146845 {'max_features': 5, 'n_estimators': 30}
# 2.2761022859685123 {'max_features': 10, 'n_estimators': 3}
# 2.139694017414631 {'max_features': 10, 'n_estimators': 10}
# 2.0745004263145095 {'max_features': 10, 'n_estimators': 30}
# 2.2662990417044164 {'max_features': 15, 'n_estimators': 3}
# 2.12480769528505 {'max_features': 15, 'n_estimators': 10}
# 2.0689174008607703 {'max_features': 15, 'n_estimators': 30}
# 2.2648915205342854 {'max_features': 25, 'n_estimators': 3}
# 2.1227849301717194 {'max_features': 25, 'n_estimators': 10}
# 2.0776708014669447 {'max_features': 25, 'n_estimators': 30}
# 2.259771392306807 {'max_features': 44, 'n_estimators': 3}
# 2.126517715471941 {'max_features': 44, 'n_estimators': 10}
# 2.0688613037793804 {'max_features': 44, 'n_estimators': 30}
# 2.273012244553945 {'bootstrap': False, 'max_features': 5, 'n_estimators': 3}
# 2.1396108101780853 {'bootstrap': False, 'max_features': 5, 'n_estimators': 10}
# 2.0730486180011933 {'bootstrap': False, 'max_features': 5, 'n_estimators': 30}
# 2.264102834123531 {'bootstrap': False, 'max_features': 10, 'n_estimators': 3}
# 2.130465966370385 {'bootstrap': False, 'max_features': 10, 'n_estimators': 10}
# 2.0685848916368803 {'bootstrap': False, 'max_features': 10, 'n_estimators': 30}
# 2.2619322412080067 {'bootstrap': False, 'max_features': 15, 'n_estimators': 3}
# 2.1280838100358253 {'bootstrap': False, 'max_features': 15, 'n_estimators': 10}
# 2.0761312990094076 {'bootstrap': False, 'max_features': 15, 'n_estimators': 30}
# 2.251777617921379 {'bootstrap': False, 'max_features': 25, 'n_estimators': 3}
# 2.1247866608514383 {'bootstrap': False, 'max_features': 25, 'n_estimators': 10}
# 2.0782767067540133 {'bootstrap': False, 'max_features': 25, 'n_estimators': 30}
# 2.1944578012170886 {'bootstrap': False, 'max_features': 44, 'n_estimators': 3}
# 2.182758404224436 {'bootstrap': False, 'max_features': 44, 'n_estimators': 10}
# 2.1786545868367995 {'bootstrap': False, 'max_features': 44, 'n_estimators': 30}

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=200),
        'max_features': randint(low=1, high=44),
    }

forest_reg = RandomForestClassifier(random_state=42)
rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=20, cv=5, scoring='neg_mean_squared_error', random_state=42)
rnd_search.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=20,
#                    param_distributions={'max_features': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000014346CD4470>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000014346CD7020>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
rnd_search.best_params_
# Out:
# {'max_features': 2, 'n_estimators': 192}

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 2.4348628209065906 {'max_features': 39, 'n_estimators': 180}
# 2.3714949263556107 {'max_features': 29, 'n_estimators': 15}
# 2.4317992789149283 {'max_features': 43, 'n_estimators': 72}
# 2.3818483200803637 {'max_features': 21, 'n_estimators': 103}
# 2.3846193682129755 {'max_features': 19, 'n_estimators': 75}
# 2.3376220129814422 {'max_features': 11, 'n_estimators': 88}
# 2.4253978829330034 {'max_features': 36, 'n_estimators': 104}
# 2.3968088693390626 {'max_features': 24, 'n_estimators': 131}
# 2.4065007959324136 {'max_features': 22, 'n_estimators': 53}
# 2.120148008868904 {'max_features': 2, 'n_estimators': 88}
# 2.4063698619406018 {'max_features': 30, 'n_estimators': 38}
# 2.1073016926369927 {'max_features': 2, 'n_estimators': 192}
# 2.3759072188515975 {'max_features': 21, 'n_estimators': 161}
# 2.3288964597621717 {'max_features': 12, 'n_estimators': 58}
# 2.399822122363429 {'max_features': 22, 'n_estimators': 89}
# 2.392485726021249 {'max_features': 27, 'n_estimators': 59}
# 2.440877087969891 {'max_features': 42, 'n_estimators': 188}
# 2.3494124883323826 {'max_features': 16, 'n_estimators': 15}
# 2.1992948101909655 {'max_features': 3, 'n_estimators': 51}
# 2.279582017766259 {'max_features': 7, 'n_estimators': 21}

# %%
final_model = rnd_search.best_estimator_

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(final_model, 
                         X_test, y_test,
                         scoring="neg_mean_squared_error", cv=10)
forest_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores' sum:", scores),
    print("Mean:", scores.mean()),
    print("Std:", scores.std())

display_scores(forest_scores)
# Out:
# Scores' sum: [2.11909794 2.10991665 2.10953783 2.11138392 2.12827092 2.09466283
#  2.1248259  2.10960097 2.10851152 2.10941154]
# Mean: 2.1125220032263377
# Std: 0.00901602545946166

# %%
import joblib
import os

def save_model(model, dist):
    file_name = f"rnd_frst_mdl_{dist}.pkl"
    file_path = os.path.join("grayhound", "models", "random_forest_class")
    os.makedirs(file_path, exist_ok=True)
    joblib.dump(model, os.path.join(file_path, file_name))

# %%
save_model(final_model, 480)
